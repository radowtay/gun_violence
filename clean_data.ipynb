# %%
#import
import pandas as pd

# %%
#bring in file
file = "Resources/gun-violence-data_01-2013_03-2018.csv"
df=pd.read_csv(file)

# %%
#preview
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
df.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
reduced_df = df.loc[:, ['incident_id','date','state', 'city_or_county','n_killed','n_injured',
                        'congressional_district','gun_type','incident_characteristics','latitude','longitude',
                        'state_house_district','state_senate_district']]
reduced_df
# Out:
#         incident_id        date           state city_or_county  n_killed  \
# 0            461105  2013-01-01    Pennsylvania     Mckeesport         0
# 1            460726  2013-01-01      California      Hawthorne         1
# 2            478855  2013-01-01            Ohio         Lorain         1
# 3            478925  2013-01-05        Colorado         Aurora         4
# 4            478959  2013-01-07  North Carolina     Greensboro         2
# ...             ...         ...             ...            ...       ...
# 239672      1083142  2018-03-31       Louisiana          Rayne         0
# 239673      1083139  2018-03-31       Louisiana   Natchitoches         1
# 239674      1083151  2018-03-31       Louisiana         Gretna         0
# 239675      1082514  2018-03-31           Texas        Houston         1
# 239676      1081940  2018-03-31           Maine   Norridgewock         2
#
#         n_injured  congressional_district                gun_type  \
# ...

# %%
gun_deaths_df = reduced_df.loc[reduced_df['n_killed'] >= 1,]
# Out:
#         incident_id        date           state city_or_county  n_killed  \
# 1            460726  2013-01-01      California      Hawthorne         1
# 2            478855  2013-01-01            Ohio         Lorain         1
# 3            478925  2013-01-05        Colorado         Aurora         4
# 4            478959  2013-01-07  North Carolina     Greensboro         2
# 5            478948  2013-01-07        Oklahoma          Tulsa         4
# ...             ...         ...             ...            ...       ...
# 239663      1082197  2018-03-31        Oklahoma        Guthrie         1
# 239666      1081894  2018-03-31        Missouri    Saint Louis         1
# 239673      1083139  2018-03-31       Louisiana   Natchitoches         1
# 239675      1082514  2018-03-31           Texas        Houston         1
# 239676      1081940  2018-03-31           Maine   Norridgewock         2
#
#         n_injured  congressional_district                gun_type  \
# ...

# %%
gun_deaths_df.to_csv('Resources/gun_deaths.csv')

# %%
reduced_df.to_csv('Resources/gun_violence.csv')
